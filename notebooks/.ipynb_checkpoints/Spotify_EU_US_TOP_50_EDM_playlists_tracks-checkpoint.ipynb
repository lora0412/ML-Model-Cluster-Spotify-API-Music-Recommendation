# %% [markdown]
# # 1. Libraries

# %%
# 1. Python 
import pandas as pd
import numpy as np

# 2. Spotify API
import requests
import base64
import time
import logging

#logging.basicConfig(level=logging.INFO)

# 3. Spotify OAuth 2.0
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %% [markdown]
# # 2. Access to API

# %%
# 2.1 Get access to API Key&Secret
import os
from dotenv import load_dotenv

# Load .env
load_dotenv()

# Get access to SPI key&Secret
client_id = os.getenv('client_id')
client_secret = os.getenv('client_secret')

# DELETE IT WHEN COMMIT!!!!!!!!!!!!! 
print(f"Spotify Client ID: {client_id}")
print(f"Spotify Client ID: {client_secret}")
# Out:
# Spotify Client ID: 44e2445f6df747e1927dd903fd225543
# Spotify Client ID: 97a1cfcc8a1044118acde9f18c7a661d

# %%
# 2.2 create client credentials
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# # 3. Search and access to Country public playlist

# %%
# 3.1 functions search playlist
def search_playlists(query, country, limit=50):
    search_results = sp.search(q=query, type='playlist', limit=limit, market=country)
    playlists = search_results['playlists']['items']
    return playlists

# %%
# 3.5 Country playlists 
def get_playlists_for_countries(query, countries, limit=50):
    all_playlists = []
    playlist_ids = set()
    for country in countries:
        playlists = search_playlists(query, country, limit)
        for playlist in playlists:
            if playlist['id'] not in playlist_ids:
                playlist_ids.add(playlist['id'])
                all_playlists.append(playlist)
    return all_playlists

# %% [markdown]
# # 4. Search Tracks in playlists

# %%
# 4.1 Get access to all playlist_tracks

def get_playlist_tracks(playlist_id):
    tracks = []
    try:
        results = sp.playlist_tracks(playlist_id)
        tracks.extend(results['items'])
        
        while results['next']:
            time.sleep(1)  # rate limit 
            results = sp.next(results)
            tracks.extend(results['items'])
    except spotipy.exceptions.SpotifyException as e:
        logging.error(f"Error fetching tracks for playlist {playlist_id}: {e}")
    
    return tracks

# %%
# 4.2 Get track features 

def get_audio_features_with_info(track_ids):
    features = []
    track_infos = []
    try:
        for i in range(0, len(track_ids), 100):  # Max 100 everytime 
            time.sleep(1)  
            features.extend(sp.audio_features(track_ids[i:i+100]))
        
        for i in range(0, len(track_ids), 50):  # Max 50 everytime 
            time.sleep(1)  
            track_infos.extend(sp.tracks(track_ids[i:i+50])['tracks'])
    except spotipy.exceptions.SpotifyException as e:
        logging.error(f"Error fetching audio features or track info: {e}")
    
    combined_info = []
    for feature, track in zip(features, track_infos):
        if feature and track:  
            combined_info.append({
                'track_id': track['id'],
                'track_name': track['name'],
                'artist_name': ', '.join([artist['name'] for artist in track['artists']]),
                'album_name': track['album']['name'],
                'release_date': track['album']['release_date'],
                'duration_ms': track['duration_ms'],
                'popularity': track['popularity'],
                'danceability': feature['danceability'],
                'energy': feature['energy'],
                'key': feature['key'],
                'loudness': feature['loudness'],
                'mode': feature['mode'],
                'speechiness': feature['speechiness'],
                'acousticness': feature['acousticness'],
                'instrumentalness': feature['instrumentalness'],
                'liveness': feature['liveness'],
                'valence': feature['valence'],
                'tempo': feature['tempo']
            })
    return combined_info

# %%
# 4.3 Get all features in playlists 

def get_playlist_audio_features(playlist_id):
    tracks = get_playlist_tracks(playlist_id)
    track_ids = [track['track']['id'] for track in tracks if track['track']['id'] is not None]
    audio_features_with_info = get_audio_features_with_info(track_ids)
    return audio_features_with_info

# %%
# EDM TOP50 playlists for 6 countries 
query = 'EDM'
countries = ['US', 'DE', 'ES', 'PT', 'GB', 'NL'] # should be 20*6 = 120 but drop the duplicates 
playlists = get_playlists_for_countries(query, countries)

all_audio_features = []
unique_track_ids = set()

for playlist in playlists:
    playlist_id = playlist['id']
    print(f"Getting audio features for playlist: {playlist['name']}")
    audio_features = get_playlist_audio_features(playlist_id)
    
    for feature in audio_features:
        if feature['track_id'] not in unique_track_ids:
            unique_track_ids.add(feature['track_id'])
            all_audio_features.append(feature)
# Out:
# Getting audio features for playlist: EDM Music 2024 (Top 100)
# Getting audio features for playlist: mint
# Getting audio features for playlist: EDM House Mix
# Getting audio features for playlist: EDM BANGERS ❤️‍🔥🤯🌎
# Getting audio features for playlist: Chill Tracks
# Getting audio features for playlist: EDM Hard Bass Mix
# Getting audio features for playlist: EDM Classics (Top 100)
# Getting audio features for playlist: Workout EDM Mix
# Getting audio features for playlist: Summer EDM Mix
# Getting audio features for playlist: Happy Beats
# Getting audio features for playlist: hot girl EDM workout mix 🎧
# Getting audio features for playlist: Pop Hits 2000s – 2024
# Getting audio features for playlist: Club EDM Mix
# Getting audio features for playlist: EDM BANGERS 🔥🎧
# Getting audio features for playlist: EDM 2024
# Getting audio features for playlist: EDM MIX 2024 🔥 EDM HITS 🔥TOMORROWLAND 2024
# Getting audio features for playlist: Ultra Gaming
# Getting audio features for playlist: Best EDM Songs of All Time - Most Popular EDM Music Playlist
# Getting audio features for playlist: BRAZILIAN PHONK 🇧🇷
# Getting audio features for playlist: Best EDM Playlist 2024
# Getting audio features for playlist: Deep House Relax
# Getting audio features for playlist: 2013-2015 EDM Hits
# Getting audio features for playlist: Dance Hits
# Getting audio features for playlist: Hype EDM Mix
# Getting audio features for playlist: Dance Party
# Getting audio features for playlist: EDM Remixes of Popular Songs
# Getting audio features for playlist: Running EDM Mix
# Getting audio features for playlist: EDM Workout 2024 | Training Hits
# Getting audio features for playlist: frat songs that could resurrect me
# Getting audio features for playlist: EDM Hits
# Getting audio features for playlist: Hype
# Getting audio features for playlist: EDM Pop Mix
# Getting audio features for playlist: Car Music
# Getting audio features for playlist: as i run (to EDM hits)
# Getting audio features for playlist: All New Dance
# Getting audio features for playlist: Top EDM Hits of All Time
# Getting audio features for playlist: Pop Remix
# Getting audio features for playlist: Party EDM Pop 2010-2024
# Getting audio features for playlist: Gym Hits
# Getting audio features for playlist: EDM beat drops😱
# Getting audio features for playlist: Night Rider
# Getting audio features for playlist: Best EDM of All Time
# Getting audio features for playlist: Power Hour
# Getting audio features for playlist: Dance EDM Mix
# Getting audio features for playlist: Dance Rising
# Getting audio features for playlist: EDM Island
# Getting audio features for playlist: Trap/Rap EDM Remix
# Getting audio features for playlist: EDM Electronica 2024
# Getting audio features for playlist: Edm Mode
# Getting audio features for playlist: EDM GYM PLAYLIST PR TIME LETS GOO
# Getting audio features for playlist: EDM PARTY 2024 🎉 EDM Dance Hits, Techno Party, EDM Main Stage, EDM Remix
# Getting audio features for playlist: 90er & 2000er Party 🎉 Partyhits, 90s & 2000s Club Anthems, Eurodance Hits
# Getting audio features for playlist: GYM BEASTMODE 2024 💪
# Getting audio features for playlist: EDM - TECHNO - DANCE - PARTY - MAIN STAGE HIT REMIX 2024 🔥 EDM HITS - EDM FESTIVAL  - TOP 100
# Getting audio features for playlist: EDM Techno Mix
# Getting audio features for playlist: RUNNING REMIX 2024  🏃 LAUFEN 👟 JOGGING 🎽 RUNNING MUSIC 2024 🏃‍♀️ RUNNING ENERGY  👟 RUNNING MOTIVATION
# Getting audio features for playlist: EDM MIX 2024  |  DANCE MUSIC  | DEEP HOUSE  | EDM HITS  | TECH HOUSE  | TECHNO
# Getting audio features for playlist: Remixes 2024 🔥 Best Popular Songs Remixed 🔥 Best Remixes & EDM Hits 2024
# Getting audio features for playlist: Music Mix 2024 🎧 EDM Remixes of Popular Songs 🎧 EDM Best Music Mix
# Getting audio features for playlist: EDM Hardstyle Mix
# Getting audio features for playlist: Big Room Dance
# Getting audio features for playlist: Kontor Top Of The Clubs 2024
# Getting audio features for playlist: 2010-2015 EDM
# Getting audio features for playlist: Deutsche EDM 💥🎧🇩🇪
# Getting audio features for playlist: Bass Boosted 2024 (Top 100) 🔥🔊
# Getting audio features for playlist: Tomorrowland 2024 Playlist 💙 EDM HITS
# Getting audio features for playlist: CAR MUSIC 2024 🔥 BADASS BASS BOOSTED EDM Remix of Popular Songs
# Getting audio features for playlist: EDM/HOUSE/TECHNO 🔊
# Getting audio features for playlist: EDM REMIXES 2024
# Getting audio features for playlist: Electro House 2024 🔥
# Getting audio features for playlist: Best of EDM 🔥 | EDM Anthems
# Getting audio features for playlist: DANCE 2024🔥HITS MIX  &  REMIXES, SUMMER 🌞, TECHNO, PARTY, WORKOUT, GYM, MAIN STAGE, OFFICIAL TOP 100
# Getting audio features for playlist: Car Music 2024 by Kontor | Rave & Techno - 100% Bass Boosted 🔥
# Getting audio features for playlist: Best Remixes Of Popular Songs 2024 EDM Bass Boosted Car Music Mix
# Getting audio features for playlist: Best Remixes of Popular Songs 2024 🔥 EDM & Techno Covers 🔥
# Getting audio features for playlist: CLUB MIX  2024 💥 DANCE MUSIC PARTY, DEEP HOUSE, TECHNO, CLUB ANTHEMS, EDM HITS, TECH HOUSE,UK HOUSE
# Getting audio features for playlist: Dance Music
# Getting audio features for playlist: EDM Hits 2024
# Getting audio features for playlist: EDM Classics 2010 - 2015
# Getting audio features for playlist: TECHNO🚨🔥FIESTAS
# Getting audio features for playlist: EDM / Techno Vibes 2024
# Getting audio features for playlist: 90s EDM Techno Mix
# Getting audio features for playlist: Dance Classics
# Getting audio features for playlist: ELECTRONICA 2024 & TOP DANCE MUSIC
# Getting audio features for playlist: 90s Dance Hits (Top 100)
# Getting audio features for playlist: Best EDM 2010s
# Getting audio features for playlist: DANCE 2024 HITS⚡FIESTA ELECTRONICA | AFTER 😎🌞 Summer 2024 🌴PARTY HITS✨🍹
# Getting audio features for playlist: USHUAIA IBIZA 2024
# Getting audio features for playlist: CAR MUSIC 2024 🔥 Car Music Hits 🔈
# Getting audio features for playlist: Latin Tech House 2024
# Getting audio features for playlist: Tomorrowland 2012, 2013 - 2024 🎪 [Tomorrowland Classics]
# Getting audio features for playlist: EUPHORIA
# Getting audio features for playlist: CARDIO GYM MIX 2024 🏃‍♀️ CARDIO ENERGY MUSIC 👟 CARDIO MOTIVATION POWER REMIX 🏃‍♀️ GYM CARDIO TRAMPOLIN MIX
# Getting audio features for playlist: EDM Samplings
# Getting audio features for playlist: EDM 2000’s
# Getting audio features for playlist: Gym Workout Motivation 2024
# Getting audio features for playlist: DANCE MUSIC 2024 🙌 Best Dance 2024 & EDM Hits 2024 & 2020s
# Getting audio features for playlist: Heart Beats
# Getting audio features for playlist: creamy
# Getting audio features for playlist: Suor EDM
# Getting audio features for playlist: Gaming Music Playlist 2024 🎮 👾
# Getting audio features for playlist: BRAZILIAN PHONK 🇧🇷
# Getting audio features for playlist: RAGE 💪 EDM WORKOUT MOTIVATION
# Getting audio features for playlist: Edmázia Mayembe Mix
# Getting audio features for playlist: Gaming Playlist
# Getting audio features for playlist: Workout Motivation 🏋️ EDM GYM MUSIC 2024 💪
# Getting audio features for playlist: Workout 2024 🔥 Exercise Music 🔥 Best Dance Music 🔥 Best Dance Pop 🔥 High Energy 🔥 Cardio 🔥
# Getting audio features for playlist: Mashups & Remixes 2024
# Getting audio features for playlist: Old School EDM Classics 💯 🎉
# Getting audio features for playlist: EDM Golden Age (2012-2013)
# Getting audio features for playlist: EDM Opera Mix
# Getting audio features for playlist: Old songs remix 2024
# Getting audio features for playlist: EDM DNB RAVE BANGERS 🔥
# Getting audio features for playlist: 90s / 00s EDM
# Getting audio features for playlist: Country EDM Mix
# Getting audio features for playlist: Platinum Dance Hits
# Getting audio features for playlist: 2010s EDM Mix
# Getting audio features for playlist: Festival EDM Bangers 2024
# Getting audio features for playlist: Summer Remix Party☀️🍹
# Getting audio features for playlist: Techno Music 2024 💊
# Getting audio features for playlist: 170 BPM Running EDM Mix
# Getting audio features for playlist: Mysteryland Festival 2024 🎪🔥 Mystery Land Festival Music Mix, EDM Hits, BigRoom

# %%
# Create DataFrame and Save 
df = pd.DataFrame(all_audio_features)

#df.to_csv('EU_US_TOP_50_EDM_playlists_tracks.csv')
