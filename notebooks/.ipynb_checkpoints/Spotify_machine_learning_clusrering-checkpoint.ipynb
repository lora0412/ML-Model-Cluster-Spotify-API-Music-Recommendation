# %% [markdown]
# # 1. Libraries

# %%
# 1. Python
import pandas as pd
import numpy as np
import glob

# 2. Machine Learning 
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# # 2. Import Dataset

# %%
import glob

list_of_files = glob.glob("../data/raw/*.csv")
df = pd.read_csv(list_of_files[0])

df
# Out:
#        Unnamed: 0                track_id              track_name  \
# 0               0  09CnYHiZ5jGT1wr1TXJ9Zt  Thank You (Not So Bad)
# 1               1  0h3Xy4V4apMraB5NuM8U7Z            Stumblin' In
# 2               2  331l3xABO0HMr1Kkyh2LZq      I Don't Wanna Wait
# 3               3  0LMwmV37RCmBO2so0szAFs                Whatever
# 4               4  6BePGk3eCan4FqaW2X8Qy3                   10:35
# ...           ...                     ...                     ...
# 12178       12178  0mlT36UaCBdLk3eWBf1xP2             Set Me Free
# 12179       12179  4D2PtwM3U40QFFBA62I49P  Valodja (Kryder Remix)
# 12180       12180  4ph6uQL9QoHBrQ1CS8sg6H                 The Dom
# 12181       12181  6Q27pKlVnjU19BAwa3WChc          Perfect - Edit
# 12182       12182  0WJ1XvutJMOUft1SDAmQU6                  Motive
#
#                                              artist_name  \
# 0      Dimitri Vegas & Like Mike, Tiësto, Dido, W&W, ...
# 1                                                  CYRIL
# 2                              David Guetta, OneRepublic
# 3                                          Kygo, Ava Max
# 4                                     Tiësto, Tate McRae
# ...                                                  ...
# 12178                            Don Diablo, RetroVision
# 12179                        Steve Angello, AN21, Kryder
# 12180                                        Will Sparks
# 12181                                         TOBEHONEST
# 12182                                   Armin van Buuren
#
#                    album_name release_date  duration_ms  popularity  \
# 0      Thank You (Not So Bad)   2023-12-01       140000          85
# 1                Stumblin' In   2023-11-10       213363          88
# 2          I Don't Wanna Wait   2024-04-05       149667          89
# 3                    Whatever   2024-01-19       178273          85
# 4                       10:35   2022-11-03       172252          74
# ...                       ...          ...          ...         ...
# 12178             Set Me Free   2023-09-01       157212          37
# 12179  Valodja (Kryder Remix)   2023-09-01       170170          29
# 12180        Accepted Concept   2023-10-06       200683          25
# 12181                 Perfect   2023-10-13       165000          19
# 12182                  Motive   2023-06-30       132380          36
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.673   0.950   11    -5.149     1       0.0488       0.02290
# 1             0.875   0.518    2    -8.388     1       0.0551       0.06380
# 2             0.681   0.714    1    -4.617     0       0.0309       0.03750
# 3             0.580   0.777    3    -5.690     1       0.0655       0.10400
# 4             0.696   0.793    8    -5.733     1       0.0970       0.06830
# ...             ...     ...  ...       ...   ...          ...           ...
# 12178         0.753   0.843    8    -4.943     1       0.1040       0.02860
# 12179         0.825   0.910    8    -4.535     1       0.2030       0.37100
# 12180         0.632   0.954    2    -4.676     1       0.0651       0.00171
# 12181         0.786   0.811    1    -6.457     1       0.0574       0.00328
# 12182         0.517   0.817    5    -5.792     0       0.3340       0.30100
#
#        instrumentalness  liveness  valence    tempo
# 0              0.082300    0.3980    0.563  150.019
# 1              0.009950    0.1250    0.370  126.089
# 2              0.000000    0.2320    0.554  129.976
# 3              0.000000    0.3420    0.589  108.005
# 4              0.000004    0.1800    0.698  120.003
# ...                 ...       ...      ...      ...
# 12178          0.885000    0.0758    0.435  125.961
# 12179          0.102000    0.5220    0.190  127.992
# 12180          0.904000    0.2680    0.123  127.983
# 12181          0.007430    0.3500    0.434  128.021
# 12182          0.000000    0.2860    0.312  126.250
#
# [12183 rows x 19 columns]
